# %%
"""MAIN_WFC.py: Matlab wrapper for steady BEM computation of the NREL5MW operational point"""
# %load_ext autoreload
# %matplotlib inline  
# %autoreload 
__author__ = 'ewan'
__author__      = "Ewan Machefaux"
__copyright__   = "Undisclosed"

import numpy as np
import time
import matlab.engine
import os
import matplotlib.pyplot as plt

print '***** START '
print os.getcwd()
initcd=os.getcwd()
print initcd
# print os.curdir
try:
    os.chdir('../BEM_v05/BEM/v05/Simulations/')
except:
    print 'already at the location'
eng = matlab.engine.start_matlab()
eng.addpath(r'/home/ewan/Work/Msc/MatlabPath/',nargout=0)
eng.addpath(r'../../')

files = [f for f in os.listdir('.') if os.path.isfile(f)]
for f in files:
    print f
    
turbine='NREL'
    
print 'run matlab'
Power, RPM, Thrust, lambdaf, PITCH, Omega, CP, CT, WScurve,\
 Vsimref, CPmax, lambda_opt, OmegaMax, pitch_opt, Powcurve, RPMcurve,CTcurve,CPcurve,Alpha  =eng.fSimulationRef(nargout=19)
eng.quit()

os.chdir(initcd)
print os.getcwd()
#SELECT r1.mean, r2.mean, r3.mean FROM speeds r1, dirs r2, powers r3 WHERE (r1.mean>=8.5) AND (r1.mean<=9.5) AND (r3.cid=831) AND (r3.qa=1) AND (r1.cid=91) AND (r2.cid=92)
    
# plt.figure()
# plt.plot(ret.WS,ret.Power)
# Out:
# ***** START
# /home/ewan/Work/PostDoc/DWMstandalone/sDWM-WFC/dev/notebooks
# /home/ewan/Work/PostDoc/DWMstandalone/sDWM-WFC/dev/notebooks
# fmin_minus_p.m
# fdp.m
# Test_SetSim.m
# Test_SimulationRef.m
# Test_PrescribedGamma.m
# fSimulationRef.m
# require.m
# fQpythontest.m
# fPlotCodeCompBEM.m
# MainBEMCompAllTipLossAEP.m
# Test_FindPitch.m
# Test_CompAllTipLoss.m
# Test_PowerCurve.m
# fControllerRef.m
# Test_SimpleRun.m
# run matlab
# /home/ewan/Work/PostDoc/DWMstandalone/sDWM-WFC/dev/notebooks

# %%
# Transform to numpy array
CP3=np.asarray(CP)
CT3=np.asarray(CT)
Omega3=np.asarray(Omega)
PITCH3=np.asarray(PITCH)
lambdaf3=np.asarray(lambdaf)
WS=np.asarray(WScurve)
RPM3=np.asarray(RPM)

Power=np.asarray(Power)
RPM=np.asarray(RPM)
Thrust=np.asarray(Thrust)
lambdaf=np.asarray(lambdaf)
PITCH=np.asarray(PITCH)
Omega=np.asarray(Omega)
CP=np.asarray(CP)
CT=np.asarray(CT)
WScurve=np.asarray(WScurve)
Vsimref=np.asarray(Vsimref)
CPmax=np.asarray(CPmax)
lambda_opt=np.asarray(lambda_opt)
OmegaMax=np.asarray(OmegaMax)
pitch_opt=np.asarray(pitch_opt)
Powcurve=np.asarray(Powcurve)
RPMcurve=np.asarray(RPMcurve)
CPcurve=np.asarray(CPcurve)
CTcurve=np.asarray(CTcurve)
Alpha=np.asarray(Alpha)

CP3[CP3>(16./27.)]=np.nan
CP3[CP3<0.]=np.nan
CT3[CT3<0.]=np.nan
# Out:
# /home/ewan/Work/PostDoc/WindfarmControl/dev/venv/lib/python2.7/site-packages/IPython/kernel/__main__.py:30: RuntimeWarning: invalid value encountered in greater
# /home/ewan/Work/PostDoc/WindfarmControl/dev/venv/lib/python2.7/site-packages/IPython/kernel/__main__.py:31: RuntimeWarning: invalid value encountered in less
# /home/ewan/Work/PostDoc/WindfarmControl/dev/venv/lib/python2.7/site-packages/IPython/kernel/__main__.py:32: RuntimeWarning: invalid value encountered in less

# %%
os.mkdir('../outputs/'+turbine+'/')
folder='../outputs/'+turbine+'/'
# folder='outputs/NY2test/'
np.save(folder+'Power.npy',Power)
np.save(folder+'RPM.npy',RPM)
np.save(folder+'Thrust.npy',Thrust)
np.save(folder+'lambdaf.npy',lambdaf)
np.save(folder+'PITCH.npy',PITCH)
np.save(folder+'Omega.npy',Omega)
np.save(folder+'CP.npy',CP)
np.save(folder+'CT.npy',CT)
np.save(folder+'WScurve.npy',WScurve)
np.save(folder+'Vsimref.npy',Vsimref)
np.save(folder+'CPmax.npy',CPmax)
np.save(folder+'lambda_opt.npy',lambda_opt)
np.save(folder+'OmegaMax.npy',OmegaMax)
np.save(folder+'pitch_opt.npy',pitch_opt)
np.save(folder+'Powcurve.npy',Powcurve)
np.save(folder+'RPMcurve.npy',RPMcurve)
np.save(folder+'CPcurve.npy',CPcurve)
np.save(folder+'CTcurve.npy',CTcurve)
np.save(folder+'Alpha.npy',Alpha)

# np.save('outputs/NY2test/Power.npy',Power)
# np.save('outputs/NY2test/RPM.npy',RPM)
# np.save('outputs/NY2test/Thrust.npy',Thrust)
# np.save('outputs/NY2test/lambdaf.npy',lambdaf)
# np.save('outputs/NY2test/PITCH.npy',PITCH)
# np.save('outputs/NY2test/Omega.npy',Omega)
# np.save('outputs/NY2test/CP.npy',CP)
# np.save('outputs/NY2test/CT.npy',CT)
# np.save('outputs/NY2test/WScurve.npy',WScurve)
# np.save('outputs/NY2test/Vsimref.npy',Vsimref)
# np.save('outputs/NY2test/CPmax.npy',CPmax)
# np.save('outputs/NY2test/lambda_opt.npy',lambda_opt)
# np.save('outputs/NY2test/OmegaMax.npy',OmegaMax)
# np.save('outputs/NY2test/pitch_opt.npy',pitch_opt)
# np.save('outputs/NY2test/Powcurve.npy',Powcurve)
# np.save('outputs/NY2test/RPMcurve.npy',RPMcurve)
# np.save('outputs/NY2test/CTcurve.npy',CTcurve)

NREL5MW_Cp_Lambda_Pitch=np.dstack((lambdaf3,PITCH3,CP3))
print NREL5MW_Cp_Lambda_Pitch.shape
NREL5MW_Ct_Lambda_Pitch=np.dstack((lambdaf3,PITCH3,CT3))
print NREL5MW_Ct_Lambda_Pitch.shape

# np.save('outputs/NY2test/Cp_Lambda_Pitch.npy',NREL5MW_Cp_Lambda_Pitch)
# np.save('outputs/NY2test/Ct_Lambda_Pitch.npy',NREL5MW_Ct_Lambda_Pitch)

np.save(folder+'Cp_Lambda_Pitch.npy',NREL5MW_Cp_Lambda_Pitch)
np.save(folder+'Ct_Lambda_Pitch.npy',NREL5MW_Ct_Lambda_Pitch)
# Out:
# (89, 35, 3)
# (89, 35, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np


# print np.diff(Omega3)
# ws1=WS[np.diff(Omega3)<0.01] #start of region 2
# ws1=ws1[0]
# I3=np.range(0,len(WS),1)
# I3=I3[Pitch>pitch_opt]
# I3=I3[0] #will I ever learn find ??
# ws2=Ws[I3] # %start of region3
# wsmin=min[WS]
# wsmax=max[WS]



# combining cases

# %%
# %load_ext autoreload
# %matplotlib inline  
# %autoreload 
import numpy as np
import time
import matlab.engine
import os
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# try:
#     os.chdiros.chdir('BEM_v05/BEM/v05/Simulations/')
# except:
#     pass

# folder='outputs/NY2test/'
# folder='./'
# folder='outputs/NRELtest/'
Power=np.load(folder+'Power.npy')
RPM=np.load(folder+'RPM.npy')
Thrust=np.load(folder+'Thrust.npy')
lambdaf=np.load(folder+'lambdaf.npy')
PITCH=np.load(folder+'PITCH.npy')
Omega=np.load(folder+'Omega.npy')
CP=np.load(folder+'CP.npy')
CT=np.load(folder+'CT.npy')
WScurve=np.load(folder+'WScurve.npy')
Vsimref=np.load(folder+'Vsimref.npy')
CPmax=np.load(folder+'CPmax.npy')
lambda_opt=np.load(folder+'lambda_opt.npy')
OmegaMax=np.load(folder+'OmegaMax.npy')
pitch_opt=np.load(folder+'pitch_opt.npy')
Powcurve=np.load(folder+'Powcurve.npy')
RPMcurve=np.load(folder+'RPMcurve.npy')
CPcurve=np.load(folder+'CPcurve.npy')
CTcurve=np.load(folder+'CTcurve.npy')
Alpha=np.load(folder+'Alpha.npy')
                   
Cp_Lambda_Pitch=np.load(folder+'Cp_Lambda_Pitch.npy')
Ct_Lambda_Pitch=np.load(folder+'Ct_Lambda_Pitch.npy')
lambdaf3=Cp_Lambda_Pitch[:,:,0]
PITCH3=Cp_Lambda_Pitch[:,:,1]
CP3=Cp_Lambda_Pitch[:,:,2]
CT3=Ct_Lambda_Pitch[:,:,2]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig = plt.figure(figsize=(10, 7))
ax = Axes3D(fig)
surf=ax.plot_surface( PITCH3, lambdaf3,CP3, rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False,shade=True,vmin=0.,vmax=0.5)
ax.set_zlim(0., 0.5)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

# ax.scatter(lambda_opt,pitch_opt,CPmax,'ko')
# plot3(lambda_opt,pitch_opt,CPmax,'ko','MarkerSize',6,'MarkerFaceColor','k');
# plot3(lambda(I3),Pitch(I3),CP(I3),'ko','MarkerSize',6,'MarkerFaceColor','k');
# plot3(lambda,Pitch,CP+0.001,'k','LineWidth',2);
    
    
# cset = ax.contourf(Omega3, PITCH3, CP3, zdir='z', offset=0, cmap=cm.coolwarm)
# cset = ax.contourf(Omega3, PITCH3, CP3, zdir='x', offset=0, cmap=cm.coolwarm)
# cset = ax.contourf(Omega3, PITCH3, CP3, zdir='y', offset=0, cmap=cm.coolwarm)

# ax.set_xlabel('X')
# ax.set_xlim(-40, 40)
# ax.set_ylabel('Y')
# ax.set_ylim(-40, 40)
# ax.set_zlabel('Z')
# ax.set_zlim(-100, 100)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f336d07ce18>

# %%
# 2D contour
plt.figure(figsize=(20,8))
# plt.figure()
plt.subplot(1,2,1)
CS=plt.contour( PITCH3,lambdaf3,CP3,20)
plt.clabel(CS,inline=1,fontsize=10)
plt.xlabel('Pitch angle deg',fontsize=10)
plt.ylabel('lambdaf',fontsize=10)
plt.title('CP')

plt.subplot(1,2,2)
CS=plt.contour( PITCH3,lambdaf3, CT3,75)
plt.clabel(CS,inline=1,fontsize=10)
plt.xlabel('Pitch angle deg',fontsize=10)
plt.ylabel('lambdaf',fontsize=10)
plt.title('CT')
# Out:
# /home/ewan/Work/PostDoc/WindfarmControl/dev/venv/local/lib/python2.7/site-packages/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /home/ewan/Work/PostDoc/WindfarmControl/dev/venv/local/lib/python2.7/site-packages/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':

# %%
# 2D contour
plt.figure(figsize=(20,10))
# plt.figure()
# plt.subplot(1,2,1)
CS=plt.contourf(PITCH3,lambdaf3,CP3,100)
CBI = plt.colorbar(CS, orientation='vertical', shrink=0.8)
# plt.clabel(CS,inline=1,fontsize=10)
# plt.xlabel('Pitch angle deg',fontsize=10)
# plt.ylabel('RPM',fontsize=10)
# plt.title('CP')

# plt.subplot(1,2,2)
CS=plt.contour(PITCH3, lambdaf3,CT3,25,colors='k')
plt.clabel(CS,inline=1,fontsize=10)
plt.xlabel('Pitch angle deg',fontsize=10)
plt.ylabel('lambdaf',fontsize=10)
plt.title('CP/CT')
plt.savefig('CPCTPITCHRPM.png')
plt.savefig('CPCTPITCHRPM.pdf')
